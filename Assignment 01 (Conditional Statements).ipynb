# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary = int(input("Enter your salary amount"))
years = int(input("Enter your years of services"))

if years > 5:
    print(f"The net amount of bonus is { salary * .5}")
else:
     bonus = 0
     print("The net bonus amount = ", bonus )
# Out:
# The net amount of bonus is 25000.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("Enter your age ?"))

if age > 17:
    print("You are eligible for voting")
else:
    print("You are not eligible for voting")
# Out:
# You are eligible for voting

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num = int(input("Enter a number and i will tell you it is even or odd"))
if num % 2==0:
  print(f"{num} it is even")
else:
 print(f"{num} It is odd")
# Out:
# 2 it is even

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num = int(input("Enter your number and i will tell you wether it is divisible by 7 ?"))

if num % 7==0:
    print(f"{num} it is divisible by 7")
else:
    print(f"{num} it is not divisible by 7")
# Out:
# 14 it is divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num = int(input("Enter your number and i will tell you wether it is multiple of 5 ?"))

if num % 5==0:
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %% [markdown]
# 6. Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = int(input("Enter length ?")) 
Breadth = int(input("Enter breadth ?")) 

if length == Breadth:
    print("It is square")
else:
    print("It is rectangle")
# Out:
# It is square

# %% [markdown]
# 7. Take two int values from user and print greatest among them.

# %%
num1 = int(input("Enter a number 1  then i will tell you which was greater "))
num2 = int(input("Enter a number 2  then i will tell you which was greater "))

if num1 > num2  :
    print(f"{num1} is greater than {num2}")
else:
    print(f"{num2} is greater than {num1}")
# Out:
# 54 is greater than 45

# %% [markdown]
# 8. A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks=float(input("Enter your marks"))

if marks > 80:
    print("your grade is A")
elif marks >=60:
    print("Your grade is B")
elif marks >=50:
    print("Your grade is C")
elif marks >=45:
    print("Your grade is D")
elif marks >=25:
    print("Your grade is E")
elif marks <25:
    print("Your grade is F")
# Out:
# your grade is A

# %% [markdown]
# 9. Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("Enter your age: "))
gender = input("Enter your gender (Male/Female): ")
marital_status = input("Enter your marital status (Y/N): ")

if gender == "Female":
    print("You will work only in urban areas")

elif gender == "Male":
    if age >20<=40:
        print("You may work anywhere")
    elif age>40<=60:
        print("You will work only in urban areas")
    else:
        print("ERROR")

else:
    print("ERROR")
# Out:
# You may work anywhere
